# %% [markdown]
# # 1. 네이버 API 사용 등록

# %% [markdown]
# - 네이버 개발자 센터
#
# - Application - 어플리케이션 등록
#
# - 어플리케이션 이름 : ds_study
#
# - 사용 API : 검색, 데이터랩
#
# - 서비스 환경 : WEB
#
# - Client ID : QWBan3eg2kVBubIkIke8
#
# - Client Secret : CicTW46GXE
#
# - https://developers.naver.com/apps/#/myapps/fP155_fIbiINbREJMUiR/overview

# %% [markdown]
# # 2. 네이버 API 사용하기

# %% [markdown]
# - https://developers.naver.com/docs/serviceapi/search/blog/blog.md#python
# - urllib : http 프로토콜에 따라 서버의 요청/응답을 처리하기 위한 모듈
# - urllib.request : 클라이언트의 요청을 처리하는 모듈
# - urllib.parse : url 주소에 대한 분석
# - 사용하는 서비스마다 오류 코드가 다르므로 공식문서를 확인하기

# %% [markdown]
# ## 검색 : 블로그(Blog)

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "QWBan3eg2kVBubIkIke8"
client_secret = "CicTW46GXE"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')) # 한글로 읽기 위해 decode 설정
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Mon, 30 Oct 2023 15:20:19 +0900",
# 	"total":420739,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>파이썬<\/b>자격증 수업내용과 취득방법",
# 			"link":"https:\/\/blog.naver.com\/ying61\/223171962293",
# 			"description":"오늘은 제가 왜 <b>파이썬<\/b>자격증을 땄고 수업내용이 어땠는지, 취득방법에 대해 한 번 포스팅 해볼게요. <b>파이썬<\/b>자격증은 1) COS Pro, 2) <b>파이썬<\/b> 마스터가 있었어요. 초보자가 따기엔 그나마 이게 쉽더라고요 ㅋ 물론... ",
# 			"bloggername":"험한 세상의 다리가 되어",
# 			"bloggerlink":"blog.naver.com\/ying61",
# 			"postdate":"20230801"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> 자격증 취득 수업 내용 정리!",
# 			"link":"https:\/\/blog.naver.com\/eunoia1017\/222968873209",
# 			"description":"<b>파이썬<\/b> 자격증 취득 수업 내용 정리! 많은 분들이 자신의 본 직업이나 N잡으로 코딩 한 번씩은 다... 오늘은 제가 왜 <b>파이썬<\/b> 자격증을 취득하게 되었는지에 대한 글을 같이 써보려고 해요! <b>파이썬<\/b> 자격증을... ",
# 			"bloggername":"반짝반짝 빛나는",
# 			"bloggerlink":"blog.naver.com\/eunoia1017",
# 			"postdate":"20221229"
# 		},
# 		{
# 			"title":"실무위주의 교육과 취업연계 대전<b>파이썬<\/b>학원",
# 			"link":"https:\/\/blog.naver.com\/montag75\/223199435463",
# 			"description":"그래서 이건 기회다 싶어 과감한 결정을 내릴 때라는 것을 깨닫고 저도 대전<b>파이썬<\/b>학원 알아봤어요. #대전<b>파이썬<\/b>학원 https:\/\/analytics.oasisbrand.co.kr\/api\/tracking\/d1e60d7c-6733-463f-a5bb-84f9b2b21187 제가 선택한 곳은... ",
# 			"bloggername":"CHIRO",
# 			"bloggerlink":"blog.naver.com\/montag75",
# 			"postdate":"20230901"
# 		},
# 		{
# 			"title":"백엔드 개발자 연봉 자바 <b>파이썬<\/b> 취업방법",
# 			"link":"https:\/\/blog.naver.com\/qislvie\/223218826697",
# 			"description":"자바 <b>파이썬<\/b> 명령어가 중요한 이유 3. 웹개발자 되는방법 사회 트렌드, 전망, 분위기 4. 내일배움카드... - 첫번째 프로그래밍 언어 배우기 : 자바 <b>파이썬<\/b> 그리고 Node.js(JavaScript), Ruby, PHP, JSP을 사용합니다.... ",
# 			"bloggername":"난 할 수 있다",
# 			"bloggerlink":"blog.naver.com\/qislvie",
# 			"postdate":"20230922"
# 		},
# 		{
# 			"title":"코딩학원 프로그래밍 AI 인공지능 로봇 게임 <b>파이썬<\/b> 자바 엔트리",
# 			"link":"https:\/\/blog.naver.com\/ijungsun\/223234862550",
# 			"description":"(김선생의 AI 코딩학원은 #<b>파이썬<\/b> #자바 #교육 에 특화되있습니다.) 그래야 미래에 쓰임받는 인재가 되겠죠 ㅎㅎ 그렇기때문에 남양주 구리에 계신 학생 학부모님들이게 김성찬의 AI 코딩학원 을 추천합니다.... ",
# 			"bloggername":"IT&재미",
# 			"bloggerlink":"blog.naver.com\/ijungsun",
# 			"postdate":"20231012"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> 생활 프로젝트 코딩 - 서승희 \/ <b>파이썬<\/b> 기초 및 독학",
# 			"link":"https:\/\/blog.naver.com\/tsslove\/223203494688",
# 			"description":"<b>파이썬<\/b> 기초 및 <b>파이썬<\/b> 독학은 이 책으로! &lt;<b>파이썬<\/b> 생활 프로젝트 코딩&gt;_서승희 학교 수업 때문에 <b>파이썬<\/b>을 접하게 되면서, 신박하게 <b>파이썬<\/b>을 사용해 보고 싶어졌다. 이제서야 겨우 간신히 <b>파이썬<\/b> 기초를 다루고... ",
# 			"bloggername":"창고같지만 금고",
# 			"bloggerlink":"blog.naver.com\/tsslove",
# 			"postdate":"20230905"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>독학을 위한 기초 정보와 용어 정리",
# 			"link":"https:\/\/blog.naver.com\/smujack\/223235460636",
# 			"description":"오늘은 <b>파이썬<\/b>독학을 위해 알아야 할 정보들과 용어 몇가지를 정리해보려고 합니다. 웹프로그래밍에... 역시 <b>파이썬<\/b>입니다. 그만큼 대중적이고 기본제공되는 라이브러리도 많아 교육용으로도 많이 쓰이지요.... ",
# 			"bloggername":"유유의 이야기 한 잔",
# 			"bloggerlink":"blog.naver.com\/smujack",
# 			"postdate":"20231013"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> 기초부터 IT 현직자의 꿀팁까지",
# 			"link":"https:\/\/blog.naver.com\/smx2town\/223190585163",
# 			"description":"요즘 가장 주목받는 코딩 언어가 있다면 바로 <b>파이썬<\/b>이라 할 수 있어요. <b>파이썬<\/b>은 범용도나 활용도가 우수해서 거의 모든 개발자가 가장 기초적으로 다룰 줄 아는 분야인데요. 요즘 코딩 관련 이슈나 교육이... ",
# 			"bloggername":"J-thing",
# 			"bloggerlink":"blog.naver.com\/smx2town",
# 			"postdate":"20230823"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>자격증 종류와 효율적인 취득법",
# 			"link":"https:\/\/blog.naver.com\/togyu911\/222989910925",
# 			"description":"실제로 많은 분들이 프로그래밍 언어나 코딩을 배우는 것은 물론, <b>파이썬<\/b>자격증 취득으로 개발직군... 바로 <b>파이썬<\/b>입니다. 프론트엔드부터 백엔드까지 모든 과정에 활용할 수 있는 것은 물론이고요. 가장... ",
# 			"bloggername":"IIS 지식정보네트워크",
# 			"bloggerlink":"blog.naver.com\/togyu911",
# 			"postdate":"20230124"
# 		},
# 		{
# 			"title":"[<b>파이썬<\/b>]환경 구축하기",
# 			"link":"https:\/\/blog.naver.com\/apdlvmf545\/223220431360",
# 			"description":"안녕하세요 재료하는데 어째서 컴공인 <b>파이썬<\/b>이냐 하면 최근에 시뮬레이션을 좀 많이... 소문난 <b>파이썬<\/b>으로 <b>파이썬<\/b>을 쓸려면 당연히 <b>파이썬<\/b>이 있어야합니다(?) 공홈으로 들어가 다운로드 탭을... ",
# 			"bloggername":"메론빵의블로그",
# 			"bloggerlink":"blog.naver.com\/apdlvmf545",
# 			"postdate":"20230924"
# 		}
# 	]
# }

# %%
response, response.getcode(), response.code, response.status
# Out:
# (<http.client.HTTPResponse at 0x7f8530ba1f10>, 200, 200, 200)

# %% [markdown]
# ## 검색 : 책(Book)

# %%
# 네이버 검색 API 예제 - 책 검색(url에서 blog -> book)
client_id = "QWBan3eg2kVBubIkIke8"
client_secret = "CicTW46GXE"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/book?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')) # 한글로 읽기 위해 decode 설정
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Mon, 30 Oct 2023 15:30:46 +0900",
# 	"total":937,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"Do it! 점프 투 파이썬 (중학생도 첫날부터 실습하는 초고속 입문서)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/40354085633",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4035408\/40354085633.20230927071024.jpg",
# 			"author":"박응용",
# 			"discount":"19800",
# 			"publisher":"이지스퍼블리싱",
# 			"pubdate":"20230615",
# 			"isbn":"9791163034735",
# 			"description":"프로그래밍 분야 8년 연속 베스트셀러!\n《Do it! 점프 투 파이썬》 전면 개정 2판 출시!\n\n중고등학생도, 비전공자도, 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이 전면 개정 2판으로 새롭게 태어났다! 챗GPT를 시작으로 펼쳐진 생성 AI 시대에 맞춰 설명과 예제를 다듬고, 최신 경향과 심화 내용을 보충했다. 또한 이번 개정 2판도 50만 코딩 유튜버인 조코딩과 협업을 통해 유튜브 동영상을 제공해 파이썬을 더 쉽게 공부할 수 있다.\n\n8년 연속 베스트셀러! 위키독스 누적 방문 300만! 독자의 입에서 입으로 전해진 추천과 수많은 대학 및 학원의 교재 채택을 통해 검증은 이미 끝났다. 코딩을 처음 배우는 중고등학생부터 코딩 소양을 기르려는 비전공자, 자기계발에 진심인 직장인까지! 이 책과 함께 파이썬 프로그래밍의 세계로 ‘점프’해 보자!"
# 		},
# 		{
# 			"title":"알고리즘 인사이드 with 파이썬 (86개 풀이로 문제 해결 능력, 사고력을 키우는 알고리즘 & 자료구조 입문서)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/43295344634",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4329534\/43295344634.20231018091440.jpg",
# 			"author":"손혁제",
# 			"discount":"34200",
# 			"publisher":"한빛미디어",
# 			"pubdate":"20231019",
# 			"isbn":"9791169211550",
# 			"description":"“17년 차 베테랑 개발자가 직접 풀고 해설한다!”\n학생, 취준생, 주니어, 역량 개발이 필요한 모든 개발자를 위한  \n86개 문제 풀이로 사고력을 키우는 알고리즘 & 자료구조 입문서\n오랫동안 많은 IT 기업은 인재를 선발하는 가장 효과적인 도구로 알고리즘 테스트를 활용해왔습니다. 문제 풀이와 개발 능력은 상관없어 보이지만, 알고리즘은 공부하면 할수록 구현 능력이 향상되고 논리력이 증가하는 '효율을 위한 도구'입니다. \n이 책은 범용성 높은 프로그래밍 언어인 파이썬을 활용해 코딩 테스트에 자주 등장하는 문제 유형 86개를 풀이하는 과정을 살펴봅니다. 17년 차 S\/W 아키텍트이자 개발자인 저자가 알려 주는 실무에도 유용한 해결 코드를 따라가다 보면 사고력과 문제 해결 능력의 기반을 다질 수 있습니다. \n알고리즘이 처음인 학생, 코딩 테스트를 앞두고 있는 취준생은 물론이고 역량을 개발하려는 현직 개발자까지 자신의 수준에 맞춰 개념을 학습하고 문제를 풀이할 수 있도록 기본 이론과 문제 풀이, 해설까지 꼼꼼하게 담았습니다."
# 		},
# 		{
# 			"title":"혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32507605957",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3250760\/32507605957.20230509170119.jpg",
# 			"author":"윤인성",
# 			"discount":"19800",
# 			"publisher":"한빛미디어",
# 			"pubdate":"20220601",
# 			"isbn":"9791162245651",
# 			"description":"혼자 해도 충분하다! 1:1 과외하듯 배우는 파이썬 프로그래밍 자습서\n\n『혼자 공부하는 파이썬』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따라갈 수 있는 친절한 설명과 단계별 학습은 그대로! 혼자 공부하더라도 체계적으로 계획을 세워 학습할 수 있도록 ‘혼공 계획표’를 새롭게 추가했습니다. 또한 입문자가 자주 물어보는 질문과 오류 해결 방법을 적재적소에 배치하여 예상치 못한 문제에 부딪혀도 좌절하지 않고 끝까지 완독할 수 있도록 도와줍니다. 단순한 문법 암기와 코딩 따라하기에 지쳤다면, 새로운 혼공파와 함께 ‘누적 예제’와 ‘도전 문제’로 프로그래밍의 신세계를 경험해 보세요! 배운 내용을 씹고 뜯고 맛보고 즐기다 보면 응용력은 물론 알고리즘 사고력까지 키워 코딩 실력이 쑥쑥 성장할 것입니다.\n\n이 책은 독학으로 파이썬을 배우는 입문자가 ‘꼭 필요한 내용을 제대로 학습’할 수 있도록 구성했습니다. 뭘 모르는지조차 모르는 입문자의 막연한 마음에 십분 공감하여 과외 선생님이 알려주듯 친절하게, 핵심적인 내용만 콕콕 집어줍니다. 책의 첫 페이지를 펼쳐서 마지막 페이지를 덮을 때까지, 혼자서도 충분히 파이썬을 배울 수 있다는 자신감과 확신이 계속될 것입니다!\n\n베타리더와 함께 입문자에게 맞는 난이도, 분량, 학습 요소 등을 적극 반영했습니다. 어려운 용어와 개념은 한 번 더 풀어쓰고, 복잡한 설명은 눈에 잘 들어오는 그림으로 풀어냈습니다. ‘혼자 공부해 본’ 여러 입문자의 초심과 눈높이가 책 곳곳에 반영된 것이 이 책의 가장 큰 장점입니다."
# 		},
# 		{
# 			"title":"2024 수제비 빅데이터분석기사 실기 R+파이썬 (작업형 제3유형 완벽 대비 + 2021년 2회~2023년 6회 기출복원문제 수록)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/43362059628",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4336205\/43362059628.20231022070924.jpg",
# 			"author":"윤영빈^조수연^이호형^박인상^김학배",
# 			"discount":"29700",
# 			"publisher":"건기원",
# 			"pubdate":"20231030",
# 			"isbn":"9791157677917",
# 			"description":"〈본서의 특징〉\nR + 파이썬(Python) 언어를 한 권으로 완벽하게 끝내기!!!\n\n첫째, 비전공자를 위한 최고의 비법서! \n잠깐! 알고 가기, 학습 Point, 개념 박살내기 등 다양한 장치 마련 \n\n둘째, 작업형에 필요한 언어 수록 \nR 언어, 파이썬 언어에 대해 기본 문법부터 기출문제까지 수록 \n\n셋째, 최강 커뮤니티를 통한 실시간 피드백 \n데일리 문제, FAQ 자료 등 제공"
# 		},
# 		{
# 			"title":"CODING BASICS PYTHON (파이썬)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32440944646",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3244094\/32440944646.20230509164030.jpg",
# 			"author":"김상민^장성식^김일태",
# 			"discount":"18000",
# 			"publisher":"렉스미디어닷넷",
# 			"pubdate":"20220210",
# 			"isbn":"9788959604210",
# 			"description":"파이썬으로 다지는 프로그래밍의 기초\n\nㆍ 다양한 예제를 활용하여 초보자도 쉽게 프로그래밍의 기본을 익힐 수 있는 파이썬 입문서입니다.\nㆍ 문법을 사전식으로 나열하지 않고 기능적인 프로그램을 하나씩 완성하면서 익힐 수 있게 구성했습니다.\nㆍ 단계별로 완성하는 장별 예제 및 연습문제를 바탕으로 자신만의 프로그램을 완성할 수 있습니다."
# 		},
# 		{
# 			"title":"파이썬",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32438172833",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3243817\/32438172833.20230920072917.jpg",
# 			"author":"김영천",
# 			"discount":"22500",
# 			"publisher":"기한재",
# 			"pubdate":"20200225",
# 			"isbn":"9788970187990",
# 			"description":"▶ 이 책은 Python(파이썬)을 다룬 이론서입니다. Python(파이썬)의 기초적이고 전반적인 내용을 학습할 수 있습니다."
# 		},
# 		{
# 			"title":"파이썬",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32441653441",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3244165\/32441653441.20230418164550.jpg",
# 			"author":"Y. Daniel Liang",
# 			"discount":"31500",
# 			"publisher":"에피스테메",
# 			"pubdate":"20180302",
# 			"isbn":"9788920028892",
# 			"description":"이 책은 누구나 쉽게 따라할 수 있는 파이썬 프로그래밍 언어에 기반하고 있기 때문에 프로그래밍을 통해 얻을 수 있는 논리 능력 향상과 문제 해결력 배양에 가장 적합하다. \n비전공자도 쉽게 이해하고 활용할 수 있는 풍부한 예제를 제공하여 프로그래밍의 기본 개념 정립에 도움을 주며 실생활과 밀접하게 관련된 다양한 사례 연구를 통해 실생활의 문제 해결 능력을 자연스럽게 배양시킨다.\n 이 책을 활용한 프로그래밍 학습을 통해 파이썬 프로그램을 스스로 작성하고 실행해 봄으로써 자신만의 프로그램을 작성할 수 있다는 뿌듯함을 느껴볼 수 있다. \n객체지향 개념과 그래픽 처리, 이벤트 처리 등이 쉽게 설명되어 있어 복잡하지 않고 간단하게 프로그램에 추가하여 다양한 기능을 가진 자신만의 프로그램도 작성해 볼 수 있다.\n이 책은 파이썬 언어에 대한 기본 문법부터 활용까지 프로그래밍에 관한 전반적인 내용을 다루고 있고 원저자의 경험과 능력, 치밀한 구성에 의해 완성한 책인 만큼 완성도 및 충실도는 매우 뛰어나다. \n그동안 무심코 넘어갔던 개념들에 대해서 다시 한 번 생각해 보는 계기를 마련해 준다. 그만큼 이 책은 파이썬 프로그래밍 언어에 대한 개념과 활용을 집대성했기 때문이다. 그래서 IT 전공자뿐만 아니라 광범위한 분야에서 프로그래밍에 관심 있는 입문자들에게 많은 도움과 개념을 정리해 줄 수 있는 책이다."
# 		},
# 		{
# 			"title":"파이썬",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32504743740",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3250474\/32504743740.20220527031429.jpg",
# 			"author":"Y. Daniel Liang",
# 			"discount":"0",
# 			"publisher":"생능출판",
# 			"pubdate":"20160205",
# 			"isbn":"9788970508504",
# 			"description":"[파이썬]은 파이썬 언어에 대한 기본 문법부터 활용까지 프로그래밍에 관한 전반적인 내용을 다루고 있다. 이 책을 활용한 프로그래밍 학습을 통해 파이썬 프로그램을 스스로 작성하고 실행해 봄으로써 자신만의 프로그램을 작성할 수 있을 것이다."
# 		},
# 		{
# 			"title":"파이썬",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32460987987",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3246098\/32460987987.20230207163755.jpg",
# 			"author":"홍의경",
# 			"discount":"29760",
# 			"publisher":"생능출판",
# 			"pubdate":"20220309",
# 			"isbn":"9788970506784",
# 			"description":"코딩 실력을 키우는 지름길은 실습이다.\n\n2008년 즈음에 검인정 중학교 교과서 정보1, 정보2, 정보3을 공저로 저술하였습니다. 그 당시에 8종류의 교과서가 검인정에 합격하였는데, 파이썬을 기반으로 하는 교과서가 2종류, C언어를 기반으로 하는 교과서가 2종류, 베이직을 기반으로 하는 교과서가 2종류, 스크래치를 기반으로 하는 교과서가 2종류였습니다.\n\n교육용 언어로 시작한 파이썬이 중학교 학생들이 비교적 쉽게 학습할 수 있는 프로그래밍 언어라고 생각했는데 10여년의 세월이 흐른 지금 파이썬이 활용되는 분야가 가히 폭발적으로 증가하였습니다. \n\n파이썬에 관한 쉽고 좋은 교재를 저술하기 위해서 인터넷에서 30,000페이지 이상의 자료를 찾아서 검토하였습니다. 어쩌면 파이썬이 첫 프로그래밍 언어일 본 교재의 독자들이 두려움 없이 파이썬을 기초부터 쉽게 공부하다가, 교재를 다 읽고 나면 “어느새 중급 수준에 도달했구나”라는 생각이 들도록  완성도 높은 교재를 목표로 하였습니다. \n\n입문자를 대상으로 하는 교재일수록 집필하는데 훨씬 더 많은 정성과 노력이 필요하다는 것을 잘 알고 있습니다. 개인적으로는 데이터베이스 전공교재를 저술할 때보다 몇 배 더 힘들었고, 공을 많이 들였습니다. \n\n원고를 버전 9까지 작성하는 동안 셀 수 없이 원고를 읽어보면서 꼭 필요하지 않은 문장은 삭제하고, 필요한 문장은 반드시 넣었습니다. 고등학교 검인정 교과서 1권, 중학교 검인정 교과서 3권, 데이터베이스 전공 교재 2권, 엑셀 교재 1권, 번역서 2권을 집필하면서 나름대로 한글을 정확하고 간결하게 표현하는데 자신이 있습니다."
# 		},
# 		{
# 			"title":"파이썬",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32489150082",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3248915\/32489150082.20230207165503.jpg",
# 			"author":"천인국",
# 			"discount":"10800",
# 			"publisher":"인피니티북스",
# 			"pubdate":"20170830",
# 			"isbn":"9791185578330",
# 			"description":"컴퓨팅 사고(Computational Thinking)는 자넷 윙 교수가 2006년에 컴퓨터 학술지에서 언급한 이후로 컴퓨터 교육 분야에서 상당한 이슈가 되고 있는 용어이다. 컴퓨팅 사고는 복잡한 문제를 분해하여 문제 안에 내재된 패턴을 찾고 추상화 단계를 거쳐서 문제를 해결하는 알고리즘을 작성하는 과정이다. 작성된 알고리즘은 사람이 수행하거나 컴퓨터를 이용하여 자동화될 수 있다. \n이 책은 컴퓨팅 사고와 파이썬을 동시에 학습할 수 있도록 기획되었다. 파이썬은 컴퓨터를 전공하지 않은 학생들도 쉽게 사용할 수 있다는 큰 장점이 있다. 컴퓨팅 사고는 흥미로운 실습 예제가 많이 필요하다. 이 책에서는 최대한 많은 실습 예제를 간추려서 파이썬으로 실습할 수 있도록 하였다. 파이썬은 다양한 애니메이션이나 가상 실습을 만들 수 있는 최적의 도구이다. 학생들은 파이썬을 통하여 컴퓨터 프로그래밍의 기본적인 개념들과 컴퓨팅 사고에서 나타나는 다양한 실습을 수행할 수 있을 것이다."
# 		}
# 	]
# }

# %% [markdown]
# ## 검색 : 카페(cafearticle)

# %%
# 네이버 검색 API 예제 - 카페 검색
client_id = "QWBan3eg2kVBubIkIke8"
client_secret ="CicTW46GXE"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/cafearticle?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')) # 한글로 읽기 위해 decode 설정
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Mon, 30 Oct 2023 15:34:31 +0900",
# 	"total":170418,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"[제31703차] 데이터 경영을 위한 <b>파이썬<\/b> \/ 윌북 (10.25 ~ 10.27)",
# 			"link":"http:\/\/cafe.naver.com\/booknbeanstalk\/1239076",
# 			"description":"위한 <b>파이썬<\/b> 부제: 성공하는 CEO의 시스템 분석 툴 원제: Python for MBAs 지은이: 마탄 그리펠, 대니얼 게타 옮긴이: 박찬성 분야: 경제경영 &gt; 경영전략 &gt; IT\/디지털경영 컴퓨터\/IT &gt; 프로그래밍 언어 &gt; <b>파이썬<\/b> 사양: 무선 | 145... ",
# 			"cafename":"북카페 책과 콩나무-(독서,서평,베스트...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/booknbeanstalk"
# 		},
# 		{
# 			"title":"학점은행제 컴퓨터공학 + 코딩 <b>파이썬<\/b> 인강! 기초 공부 독학해요",
# 			"link":"http:\/\/cafe.naver.com\/outcampus\/738573",
# 			"description":"학점은행제 컴퓨터공학 + 코딩 <b>파이썬<\/b> 인강! 기초 공부 독학해요 디지털 시대의 본격화로 IT 전문가에 대한... 및 <b>파이썬<\/b> 기초가 필요하신 분들에게는 트렌디한 기초 강의도 연계해드리고 있어요~! 학점은행제 컴퓨터공학... ",
# 			"cafename":"[아웃캠퍼스] 대학생 공모전 대외활동...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/outcampus"
# 		},
# 		{
# 			"title":"왕초보인데 <b>파이썬<\/b> 마스터 자격증",
# 			"link":"http:\/\/cafe.naver.com\/sqlpd\/60984",
# 			"description":"문과라서 코딩 잘 모르고 그런데 논문을 위해서 <b>파이썬<\/b>을 하게 되었는데요. 웹크롤링을 통해서 <b>파이썬<\/b>을 해서 논문을 결국엔 <b>파이썬<\/b> 부분은 코딩 의뢰해서 완성했습니다. 그러다가 계속 배워야겠다 생각하고 adsp... ",
# 			"cafename":"데이터 전문가 포럼 (빅데이터분석기사...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/sqlpd"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>공부 이해하기 쉬운 강의와 함께라면?",
# 			"link":"http:\/\/cafe.naver.com\/hotengnet\/933550",
# 			"description":"오늘은 <b>파이썬<\/b>공부에 대해 이야기하고자 합니다. <b>파이썬<\/b>은 초보자들도 쉽게 배울 수 있다는 장점으로 프로그래밍 언어에 입문한다는 목표가 있는 분들이 먼저 시작하는 경우가 많은 언어입니다. <b>파이썬<\/b>은 데이터를... ",
# 			"cafename":"취준생★스펙뽀개기★연봉,인적성,이력...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/hotengnet"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>의 편리함",
# 			"link":"http:\/\/cafe.naver.com\/indiedev\/72889",
# 			"description":"데이터를 구성하기 위해서 list와 json등을 다루는 중인데 새삼 <b>파이썬<\/b>이 얼마나 편한 언어였는지 느끼네요 전 첫 언어가 <b>파이썬<\/b>이라 그때는 잘몰랐습니다. c#보다 c++은 더 힘들겠죠? 요즘 유니티의 요금 정책때문에... ",
# 			"cafename":"인디터 - 게임 제작자 커뮤니티",
# 			"cafeurl":"https:\/\/cafe.naver.com\/indiedev"
# 		},
# 		{
# 			"title":"김포 고촌 직장인 코딩 학원 C언어 <b>파이썬<\/b> 자바스크립트 컴퓨터 과외",
# 			"link":"http:\/\/cafe.naver.com\/jikup2\/467752",
# 			"description":"김포 고촌 직장인 코딩 학원 C언어 <b>파이썬<\/b> 자바스크립트 컴퓨터 과외 학원에서는 함께 다양한 코딩의 그림과... 어린이들은 동화책 큰 초1부터 감상하며 날, 어린이들의 학원 특별한 C언어와 초등 <b>파이썬<\/b>을 키워나갔다.... ",
# 			"cafename":"좋은 직업상담사를 꿈꾸는 사람들",
# 			"cafeurl":"https:\/\/cafe.naver.com\/jikup2"
# 		},
# 		{
# 			"title":"[코딩] c언어나 <b>파이썬<\/b> 어느정도 배워야 정올준비하나요?",
# 			"link":"http:\/\/cafe.naver.com\/mathall\/2685263",
# 			"description":"집에 컴쪽전공은 전무합니다..사실 아두이노가 뭔지도 몰라요ㅠ 무지한질문일수있는데..ㅠㅜ 초6에 정올 계획이라면 블록코딩에서 <b>파이썬<\/b> c언어로 언제쯤 넘어가야할까요? 정올시험이 수학시험이 중요하다 들었어요... ",
# 			"cafename":"[상위1%카페] 대한민국 상위1% 교육정...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/mathall"
# 		},
# 		{
# 			"title":"[달지] 건프라가 아니라 죄송합니다. <b>파이썬<\/b> 기초적인 질문입니다-해결",
# 			"link":"http:\/\/cafe.naver.com\/dalongnet\/80442",
# 			"description":"그것도 건프라가 아니라 <b>파이썬<\/b> 기초적인 질문이네요.. ^^:: 먼저 저는 <b>파이썬<\/b>을 필요때문에 설치는 했지만 전혀 작동 원리는 모르는 수준입니다. 최근 설치형 이미지 생성 AI인 스테이블 디퓨전을... ",
# 			"cafename":"D network",
# 			"cafeurl":"https:\/\/cafe.naver.com\/dalongnet"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>보다 R 이 공부하기 더 쉬울까요?",
# 			"link":"http:\/\/cafe.naver.com\/sqlpd\/62025",
# 			"description":"직장인에 비전공자에 개발자도 아닙니다 자격증은 공부 동기를 만들고자 응시하고 있고 <b>파이썬<\/b>은 기초... <b>파이썬<\/b> 기초부터 공부하려니 이게 익숙해지려면 시간이 많이 걸릴거같아서 R 이 통계에 더 적합한 프로그램이라... ",
# 			"cafename":"데이터 전문가 포럼 (빅데이터분석기사...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/sqlpd"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>강의 듣고 <b>파이썬<\/b>독학",
# 			"link":"http:\/\/cafe.naver.com\/hotengnet\/933190",
# 			"description":"오늘은 <b>파이썬<\/b>강의를 소개드리려고합니다 <b>파이썬<\/b>강의를 듣고 <b>파이썬<\/b>독학을 하려 마음먹고 계시는 분들을 위해 도움이되는 강의사이트와 정보를 노베이스 부터 시작하기에 적합한 분들에게 맞추어 공유 해드리도록... ",
# 			"cafename":"취준생★스펙뽀개기★연봉,인적성,이력...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/hotengnet"
# 		}
# 	]
# }

# %% [markdown]
# ## 검색 : 쇼핑(shop)

# %%
# 네이버 검색 API 예제 - 쇼핑 검색
client_id = "QWBan3eg2kVBubIkIke8"
client_secret = "CicTW46GXE"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')) # 한글로 읽기 위해 decode 설정
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Mon, 30 Oct 2023 15:36:13 +0900",
# 	"total":146256,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"혼자 공부하는 <b>파이썬<\/b>  1:1 과외 배우는 프로그래밍 자습서 (개정판)",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=40501298189",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4050129\/40501298189.1.jpg",
# 			"lprice":"24930",
# 			"hprice":"",
# 			"mallName":"인터파크쇼핑",
# 			"productId":"40501298189",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"출산\/육아",
# 			"category2":"교구",
# 			"category3":"학습교구",
# 			"category4":"기타교구"
# 		},
# 		{
# 			"title":"점프 투 <b>파이썬<\/b> (전면 개정판) 책",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=40230844404",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4023084\/40230844404.1.jpg",
# 			"lprice":"24800",
# 			"hprice":"",
# 			"mallName":"인터파크쇼핑",
# 			"productId":"40230844404",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"출산\/육아",
# 			"category2":"교구",
# 			"category3":"학습교구",
# 			"category4":"기타교구"
# 		},
# 		{
# 			"title":"[롯데아이몰][봄봄북스] <b>파이썬<\/b> 자동화 교과서",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=41769912735",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4176991\/41769912735.1.jpg",
# 			"lprice":"23310",
# 			"hprice":"",
# 			"mallName":"인터파크쇼핑",
# 			"productId":"41769912735",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"출산\/육아",
# 			"category2":"교구",
# 			"category3":"학습교구",
# 			"category4":"기타교구"
# 		},
# 		{
# 			"title":"혼자 공부하는 <b>파이썬<\/b> 1:1 과외 배우는 프로그래밍 자습서 (개정판)",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=40503957601",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4050395\/40503957601.jpg",
# 			"lprice":"26700",
# 			"hprice":"",
# 			"mallName":"쿠팡",
# 			"productId":"40503957601",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"출산\/육아",
# 			"category2":"교구",
# 			"category3":"학습교구",
# 			"category4":"기타교구"
# 		},
# 		{
# 			"title":"[제이북스] 난생처음 <b>파이썬<\/b> 프로그래밍",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=42509328367",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4250932\/42509328367.jpg",
# 			"lprice":"24000",
# 			"hprice":"",
# 			"mallName":"롯데ON",
# 			"productId":"42509328367",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"한빛아카데미",
# 			"category1":"출산\/육아",
# 			"category2":"교구",
# 			"category3":"학습교구",
# 			"category4":"기타교구"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>과 마이크로비트로 배우는 실전 코딩 프로젝트 교재",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=42655522751",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4265552\/42655522751.jpg",
# 			"lprice":"18900",
# 			"hprice":"",
# 			"mallName":"아이씨뱅큐",
# 			"productId":"42655522751",
# 			"productType":"2",
# 			"brand":"아이씨뱅큐",
# 			"maker":"",
# 			"category1":"출산\/육아",
# 			"category2":"교구",
# 			"category3":"학습교구",
# 			"category4":"기타교구"
# 		},
# 		{
# 			"title":"[봄봄북스] Do it 쉽게 배우는 <b>파이썬<\/b> 데이터 분석",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=41751861736",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4175186\/41751861736.jpg",
# 			"lprice":"20700",
# 			"hprice":"",
# 			"mallName":"롯데ON",
# 			"productId":"41751861736",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"이지스퍼블리싱",
# 			"category1":"출산\/육아",
# 			"category2":"교구",
# 			"category3":"학습교구",
# 			"category4":"기타교구"
# 		},
# 		{
# 			"title":"한빛미디어 <b>파이썬<\/b>으로 웹 크롤러 만들기 (개정판)",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=41112105302",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4111210\/41112105302.jpg",
# 			"lprice":"22500",
# 			"hprice":"",
# 			"mallName":"G마켓",
# 			"productId":"41112105302",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"한빛미디어",
# 			"category1":"출산\/육아",
# 			"category2":"교구",
# 			"category3":"학습교구",
# 			"category4":"기타교구"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>과 마이크로비트로 배우는 실전 코딩 프로젝트 키트 + 교재",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=42655502165",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4265550\/42655502165.jpg",
# 			"lprice":"100000",
# 			"hprice":"",
# 			"mallName":"아이씨뱅큐",
# 			"productId":"42655502165",
# 			"productType":"2",
# 			"brand":"아이씨뱅큐",
# 			"maker":"",
# 			"category1":"출산\/육아",
# 			"category2":"교구",
# 			"category3":"학습교구",
# 			"category4":"기타교구"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>을 활용한 금융 분석",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=41090215560",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4109021\/41090215560.jpg",
# 			"lprice":"40500",
# 			"hprice":"",
# 			"mallName":"G마켓",
# 			"productId":"41090215560",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"출산\/육아",
# 			"category2":"교구",
# 			"category3":"학습교구",
# 			"category4":"기타교구"
# 		}
# 	]
# }

# %% [markdown]
# ## 검색 : 백과사전(encyc)

# %%
# 네이버 검색 API 예제 - 백과사전 검색
client_id =  "QWBan3eg2kVBubIkIke8"
client_secret = "CicTW46GXE"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/encyc?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')) # 한글로 읽기 위해 decode 설정
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Mon, 30 Oct 2023 15:36:16 +0900",
# 	"total":45,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>파이썬<\/b>",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3580815&cid=59088&categoryId=59096",
# 			"description":"‘<b>파이썬<\/b>’이다. 간결한 문법으로 입문자가 이해하기 쉽고, 다양한 분야에 활용할 수 있기 때문이다. 이 외에도 <b>파이썬<\/b>은 머신러닝, 그래픽, 웹 개발 등 여러 업계에서 선호하는 언어로 꾸준히... ",
# 			"thumbnail":"http:\/\/openapi-dbscthumb.phinf.naver.net\/4749_000_1\/20170118193349632_0CHSSS5Y6.png\/01_16.png?type=m160_160"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3607513&cid=58598&categoryId=59316",
# 			"description":" 컴퓨터 언어의 일종으로 간결하고 생산성 높은 프로그래밍 언어.  <b>파이썬<\/b>(python)은 프로그램을 설계하는 프로그래밍 언어 중 하나입니다. 컴퓨터는 0과 1을(이진수) 인식하여 작동하기 때문에 과거에는... ",
# 			"thumbnail":"http:\/\/openapi-dbscthumb.phinf.naver.net\/4751_000_3\/20170710213206672_OPHLG2VOW.jpg\/992_170575_10034.jpg?type=m160_160"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3533295&cid=40942&categoryId=32838",
# 			"description":" 오픈소스 고급 프로그래밍 언어 중 하나이다.  C언어를 기반으로 한 오픈소스 고급 프로그래밍 언어로, 1991년 귀도 반 로섬(Guido van Rossum)에 의해 설계 및 개발되었다. <b>파이썬<\/b>이라는 이름은 <b>파이썬<\/b>을... ",
# 			"thumbnail":""
# 		},
# 		{
# 			"title":"장고",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=4367087&cid=59088&categoryId=59096",
# 			"description":" 장고는 <b>파이썬<\/b> 기반 웹 애플리케이션 프레임워크다. 좀 더 쉽게 웹 개발을 할 수 있게 돕는 오픈소스 기술이다. 장고는 개발 과정을 단축시켜주고, 다양한 추가 기능을 포함하고 있으며 보안성이... ",
# 			"thumbnail":"https:\/\/dthumb-phinf.pstatic.net\/?src=%22https%3A%2F%2Fpost-phinf.pstatic.net%2FMjAxNzEyMTVfMTM1%2FMDAxNTEzMzI3NDI4MjIz.nZhrYOO1nwD5YToYQRQoI8UH4MdHD8_SOjO2Uu_A45Ug.Is-NiXSP4wOgQDVNW_8j6QrMId6m1vlOohGSK1pEHa0g.JPEG%2FIjqeSPB8TSqGe9ibG3dK_hGmkobI.jpg%3Ftype%3Dm4500_4500_fst%22&type=w540#540x405#c405"
# 		},
# 		{
# 			"title":"루비 (프로그래밍 언어)",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3581025&cid=59088&categoryId=59096",
# 			"description":"C언어는 미국, 자바(Java)는 캐나다, <b>파이썬<\/b>(Python)은 네덜란드, 스칼라(Scala)는 스위스에서 나오는 식이다. 이러한 환경에서 주류 언어이자 주목받은 새로운 언어 중 아시아 지역에서 탄생한 유일한 언어가... ",
# 			"thumbnail":"http:\/\/openapi-dbscthumb.phinf.naver.net\/4749_000_10\/20170404204312715_1X732KEQK.png\/1_40.png?type=m160_160"
# 		},
# 		{
# 			"title":"오토GPT",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=6690638&cid=43667&categoryId=43667",
# 			"description":" 사용자가 목표를 설정하면 인공지능(AI)이 자동으로 인터넷을 검색하고 방법을 탐색해 결과물을 내놓는 생성형 AI로, AI 스타트업 시그니피컨트 그래피타스가 2023년 3월 30일 개발자 코드... ",
# 			"thumbnail":""
# 		},
# 		{
# 			"title":"Gensim",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=6653626&cid=69974&categoryId=69974",
# 			"description":"Gensim은 <b>파이썬<\/b>과 NumPy(숫자의 연산을 행렬 등의 형태로 쉽게 처리할 수 있게 하는 <b>파이썬<\/b> 라이브러리)를 지원하기만 하면 어떤 운영체제와도 호환된다. 무엇보다도 데이터 스트리밍을... ",
# 			"thumbnail":""
# 		},
# 		{
# 			"title":"Perplexity",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=6653705&cid=69974&categoryId=69974",
# 			"description":"언어 모델링 과정이나 음성 인식에서 엔트로피를 계산할 때에는 0에 가까운 작은 확률값이 나오는 경우가 많은데, <b>파이썬<\/b>에서는 이러한 값을 0으로 근사시키는 underflow가 발생한다는 문제가... ",
# 			"thumbnail":"https:\/\/dthumb-phinf.pstatic.net\/?src=%22https%3A%2F%2Fpost-phinf.pstatic.net%2FMjAyMjA4MjhfNDgg%2FMDAxNjYxNjkyMTczMjI3.2IEVYNlzKicXI-yYu3-JtNBl7gRGusb-i2UPfFozT_8g.uIhO9ts858Cr4VooW7qsTgRI9wtLI2mrwFpcIPxBIM8g.GIF%2FIo8p_EY-DJjgmP-xdX2ktfuv61XY.jpg%3Ftype%3Dm4500_4500_fst%22&type=w540#540x120"
# 		},
# 		{
# 			"title":"조프",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3436079&cid=42346&categoryId=42346",
# 			"description":"<b>파이썬<\/b>(Python) 프로그래밍 언어로 작성된 웹 애플리케이션 서버 구현 관련 기술. 객체 기술 기능, 폴더ㆍ파일ㆍ이미지용 프레임워크, 객체 데이터베이스, 웹 페이지 생성 템플릿, 구조화 질의 언어(SQL) 방법... ",
# 			"thumbnail":""
# 		},
# 		{
# 			"title":"행동 프로그래밍",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=5762303&cid=42107&categoryId=42107",
# 			"description":"다양한 컴퓨터 언어(<b>파이썬<\/b>, C++, 자바 등)를 이용해 로봇에 명령을 전달하는 작업. ROS(로봇오퍼레이팅시스템)가 대표적이다. 오픈소스 라이선스인 ROS는 복잡하고 강렬한 로봇 동작을 단순화하는 ‘도구... ",
# 			"thumbnail":""
# 		}
# 	]
# }

# %% [markdown]
# # 3. 상품 검색

# %% [markdown]
# - "몰스킨" 노트 검색

# %%
# 네이버 검색 API 예제 - 쇼핑 검색
client_id = "QWBan3eg2kVBubIkIke8"
client_secret = "CicTW46GXE"
encText = urllib.parse.quote("몰스킨")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')) # 한글로 읽기 위해 decode 설정
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Mon, 30 Oct 2023 16:08:27 +0900",
# 	"total":41743,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>몰스킨<\/b> 2024 위클리 다이어리 포켓 상품선택",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=42445452123",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4244545\/42445452123.20230906151250.jpg",
# 			"lprice":"29480",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"42445452123",
# 			"productType":"1",
# 			"brand":"몰스킨",
# 			"maker":"",
# 			"category1":"생활\/건강",
# 			"category2":"문구\/사무용품",
# 			"category3":"다이어리\/플래너",
# 			"category4":"다이어리"
# 		},
# 		{
# 			"title":"올젠 남성 가을겨울 <b>몰스킨<\/b> 자켓 ZOC3KG13122",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=41898585909",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4189858\/41898585909.20231028172014.jpg",
# 			"lprice":"70390",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"41898585909",
# 			"productType":"1",
# 			"brand":"올젠",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"재킷",
# 			"category4":""
# 		},
# 		{
# 			"title":"로이텀 2024 다이어리 데일리 하드커버 A5",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=86743260710",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8674326\/86743260710.1.jpg",
# 			"lprice":"31450",
# 			"hprice":"",
# 			"mallName":"몰스킨스토어",
# 			"productId":"86743260710",
# 			"productType":"2",
# 			"brand":"로이텀",
# 			"maker":"로이텀",
# 			"category1":"생활\/건강",
# 			"category2":"문구\/사무용품",
# 			"category3":"다이어리\/플래너",
# 			"category4":"다이어리"
# 		},
# 		{
# 			"title":"인디안 INDIAN 오리지널 <b>몰스킨<\/b> 셋업 자켓 MITFAWF9101",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=39838076389",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3983807\/39838076389.20230507104902.jpg",
# 			"lprice":"56380",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"39838076389",
# 			"productType":"1",
# 			"brand":"인디안",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"재킷",
# 			"category4":""
# 		},
# 		{
# 			"title":"<b>몰스킨<\/b> 2024 위클리 다이어리 라지 상품선택",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=42444253256",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4244425\/42444253256.20230906161929.jpg",
# 			"lprice":"38760",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"42444253256",
# 			"productType":"1",
# 			"brand":"몰스킨",
# 			"maker":"몰스킨",
# 			"category1":"생활\/건강",
# 			"category2":"문구\/사무용품",
# 			"category3":"다이어리\/플래너",
# 			"category4":"다이어리"
# 		},
# 		{
# 			"title":"<b>몰스킨<\/b> 2024 다이어리 클래식 소프트커버 위클리 포켓 2024년 24년",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=86678199160",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8667819\/86678199160.2.jpg",
# 			"lprice":"32400",
# 			"hprice":"",
# 			"mallName":"베스트펜",
# 			"productId":"86678199160",
# 			"productType":"2",
# 			"brand":"몰스킨",
# 			"maker":"몰스킨",
# 			"category1":"생활\/건강",
# 			"category2":"문구\/사무용품",
# 			"category3":"다이어리\/플래너",
# 			"category4":"다이어리"
# 		},
# 		{
# 			"title":"<b>몰스킨<\/b> 2024 데일리 다이어리 포켓 상품선택",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=42473541158",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4247354\/42473541158.20230907073601.jpg",
# 			"lprice":"31420",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"42473541158",
# 			"productType":"1",
# 			"brand":"몰스킨",
# 			"maker":"",
# 			"category1":"생활\/건강",
# 			"category2":"문구\/사무용품",
# 			"category3":"다이어리\/플래너",
# 			"category4":"다이어리"
# 		},
# 		{
# 			"title":"시리즈 역시즌 <b>몰스킨<\/b> 스탠카라 점퍼 SAUAW22201OLL",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=42934925866",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4293492\/42934925866.20231028061744.jpg",
# 			"lprice":"212970",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"42934925866",
# 			"productType":"1",
# 			"brand":"시리즈",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"점퍼",
# 			"category4":""
# 		},
# 		{
# 			"title":"에디션앤드지 에디션 <b>몰스킨<\/b> 셋업 자켓 NEC4KG1651",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=42833085693",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4283308\/42833085693.20230927092443.jpg",
# 			"lprice":"70000",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"42833085693",
# 			"productType":"1",
# 			"brand":"에디션앤드지",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"재킷",
# 			"category4":""
# 		},
# 		{
# 			"title":"에디션 <b>몰스킨<\/b> 셋업 자켓 NED3KG1651",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=42796441618",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4279644\/42796441618.20230921172338.jpg",
# 			"lprice":"113280",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"42796441618",
# 			"productType":"1",
# 			"brand":"에디션",
# 			"maker":"신성통상",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"재킷",
# 			"category4":""
# 		}
# 	]
# }

# %% [markdown]
# ## (1) get_search_url : 페이지에 나타난 검색 결과를 저장해주는 함수

# %%
"""
encText = urllib.parse.quote("몰스킨")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # JSON 결과
"""

# %%
def get_search_url(api_node, search_text, start_num, disp_num):
    """
    api_node : 쇼핑, 블로그, 카페 등 어디에서 검색할 것인지
    search_text : 검색어
    start_num : 검색 시작 위치
    disp_num : 한 번에 표시할 검색 결과 개수
    """
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)
    
    return base + node + param_query + param_start + param_disp

# %%
get_search_url("shop", "TEST", 10,3)
# Out:
# 'https://openapi.naver.com/v1/search/shop.json?query=TEST&start=10&display=3'

# %% [markdown]
# ## (2) get_result_onpage`: 페이지에 나타난 검색 결과를 저장해주는 함수

# %%
"""
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
"""

# %%
import json
import datetime

client_id = "fP155_fIbiINbREJMUiR"
client_secret = "hCFcz0YTay"

def get_result_onpage(url):
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    print("[%s] Url Request Success" % datetime.datetime.now())
    return json.loads(response.read().decode("utf-8"))#json으로 받겠다는 의미

# %%
url = get_search_url("shop", "몰스킨", 1,5)
one_result = get_result_onpage(url)
one_result
# Out:
# [2023-10-30 17:46:44.512450] Url Request Success
# {'lastBuildDate': 'Mon, 30 Oct 2023 17:46:44 +0900',
#  'total': 41940,
#  'start': 1,
#  'display': 5,
#  'items': [{'title': '<b>몰스킨</b> 2024 위클리 다이어리 포켓 상품선택',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=42445452123',
#    'image': 'https://shopping-phinf.pstatic.net/main_4244545/42445452123.20230906151250.jpg',
#    'lprice': '29460',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '42445452123',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '올젠 남성 가을겨울 <b>몰스킨</b> 자켓 ZOC3KG13122',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=41898585909',
#    'image': 'https://shopping-phinf.pstatic.net/main_4189858/41898585909.20231028172014.jpg',
#    'lprice': '70390',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '41898585909',
#    'productType': '1',
#    'brand': '올젠',
#    'maker': '',
#    'category1': '패션의류',
#    'category2': '남성의류',
#    'category3': '재킷',
#    'category4': ''},
#   {'title': '로이텀 2024 다이어리 데일리 하드커버 A5',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=86743260710',
#    'image': 'https://shopping-phinf.pstatic.net/main_8674326/86743260710.1.jpg',
#    'lprice': '31450',
#    'hprice': '',
#    'mallName': '몰스킨스토어',
#    'productId': '86743260710',
#    'productType': '2',
#    'brand': '로이텀',
#    'maker': '로이텀',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '인디안 INDIAN 오리지널 <b>몰스킨</b> 셋업 자켓 MITFAWF9101',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=39838076389',
#    'image': 'https://shopping-phinf.pstatic.net/main_3983807/39838076389.20230507104902.jpg',
#    'lprice': '56380',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '39838076389',
#    'productType': '1',
#    'brand': '인디안',
#    'maker': '',
#    'category1': '패션의류',
#    'category2': '남성의류',
#    'category3': '재킷',
#    'category4': ''},
#   {'title': '<b>몰스킨</b> 2024 위클리 다이어리 라지 상품선택',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=42444253256',
#    'image': 'https://shopping-phinf.pstatic.net/main_4244425/42444253256.20230906161929.jpg',
#    'lprice': '38760',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '42444253256',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'}]}

# %%
one_result["items"]
# Out:
# [{'title': '<b>몰스킨</b> 2024 위클리 다이어리 포켓 상품선택',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=42445452123',
#   'image': 'https://shopping-phinf.pstatic.net/main_4244545/42445452123.20230906151250.jpg',
#   'lprice': '29460',
#   'hprice': '',
#   'mallName': '네이버',
#   'productId': '42445452123',
#   'productType': '1',
#   'brand': '몰스킨',
#   'maker': '',
#   'category1': '생활/건강',
#   'category2': '문구/사무용품',
#   'category3': '다이어리/플래너',
#   'category4': '다이어리'},
#  {'title': '올젠 남성 가을겨울 <b>몰스킨</b> 자켓 ZOC3KG13122',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=41898585909',
#   'image': 'https://shopping-phinf.pstatic.net/main_4189858/41898585909.20231028172014.jpg',
#   'lprice': '70390',
#   'hprice': '',
#   'mallName': '네이버',
#   'productId': '41898585909',
#   'productType': '1',
#   'brand': '올젠',
#   'maker': '',
#   'category1': '패션의류',
#   'category2': '남성의류',
#   'category3': '재킷',
#   'category4': ''},
#  {'title': '로이텀 2024 다이어리 데일리 하드커버 A5',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=86743260710',
#   'image': 'https://shopping-phinf.pstatic.net/main_8674326/86743260710.1.jpg',
#   'lprice': '31450',
#   'hprice': '',
#   'mallName': '몰스킨스토어',
#   'productId': '86743260710',
#   'productType': '2',
#   'brand': '로이텀',
#   'maker': '로이텀',
#   'category1': '생활/건강',
#   'category2': '문구/사무용품',
#   'category3': '다이어리/플래너',
#   'category4': '다이어리'},
#  {'title': '인디안 INDIAN 오리지널 <b>몰스킨</b> 셋업 자켓 MITFAWF9101',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=39838076389',
#   'image': 'https://shopping-phinf.pstatic.net/main_3983807/39838076389.20230507104902.jpg',
#   'lprice': '56380',
#   'hprice': '',
#   'mallName': '네이버',
#   'productId': '39838076389',
#   'productType': '1',
#   'brand': '인디안',
#   'maker': '',
#   'category1': '패션의류',
#   'category2': '남성의류',
#   'category3': '재킷',
#   'category4': ''},
#  {'title': '<b>몰스킨</b> 2024 위클리 다이어리 라지 상품선택',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=42444253256',
#   'image': 'https://shopping-phinf.pstatic.net/main_4244425/42444253256.20230906161929.jpg',
#   'lprice': '38760',
#   'hprice': '',
#   'mallName': '네이버',
#   'productId': '42444253256',
#   'productType': '1',
#   'brand': '몰스킨',
#   'maker': '몰스킨',
#   'category1': '생활/건강',
#   'category2': '문구/사무용품',
#   'category3': '다이어리/플래너',
#   'category4': '다이어리'}]

# %%
len(one_result["items"])
# Out:
# 5

# %% [markdown]
# ## (3) get_fileds : 검색된 내용을 데이터프레임으로 저장해주는 함수

# %%
one_result["items"][0]
# Out:
# {'title': '<b>몰스킨</b> 2024 위클리 다이어리 포켓 상품선택',
#  'link': 'https://search.shopping.naver.com/gate.nhn?id=42445452123',
#  'image': 'https://shopping-phinf.pstatic.net/main_4244545/42445452123.20230906151250.jpg',
#  'lprice': '29460',
#  'hprice': '',
#  'mallName': '네이버',
#  'productId': '42445452123',
#  'productType': '1',
#  'brand': '몰스킨',
#  'maker': '',
#  'category1': '생활/건강',
#  'category2': '문구/사무용품',
#  'category3': '다이어리/플래너',
#  'category4': '다이어리'}

# %%
one_result["items"][0]["title"]
# Out:
# '<b>몰스킨</b> 2024 위클리 다이어리 포켓 상품선택'

# %%
one_result["items"][0]["link"]
# Out:
# 'https://search.shopping.naver.com/gate.nhn?id=42445452123'

# %%
one_result["items"][0]["lprice"]
# Out:
# '29460'

# %%
one_result["items"][0]["mallName"]
# Out:
# '네이버'

# %%
import pandas as pd

def get_fields(json_data):
    title = [each["title"] for each in json_data["items"]]
    link = [each["link"] for each in json_data["items"]]
    lprice = [each["lprice"] for each in json_data["items"]]
    mallName = [each["mallName"] for each in json_data["items"]]
    
    result_pd = pd.DataFrame({
        "title" : title,
        "link" : link,
        "lprice" : lprice,
        "mallName" : mallName        
    }, columns = ["title", "lprice", "link", "mallName"])
    
    return result_pd

# %%
get_fields(one_result)
# Out:
#                                           title lprice  \
# 0              <b>몰스킨</b> 2024 위클리 다이어리 포켓 상품선택  29460
# 1          올젠 남성 가을겨울 <b>몰스킨</b> 자켓 ZOC3KG13122  70390
# 2                     로이텀 2024 다이어리 데일리 하드커버 A5  31450
# 3  인디안 INDIAN 오리지널 <b>몰스킨</b> 셋업 자켓 MITFAWF9101  56380
# 4              <b>몰스킨</b> 2024 위클리 다이어리 라지 상품선택  38760
#
#                                                 link mallName
# 0  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...   몰스킨스토어
# 3  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...      네이버

# %%
# <b>태그가 포함되어있음

def delete_tag(input_str):
    input_str = input_str.replace("<b>", "")
    input_str = input_str.replace("</b>", "")
    return input_str

# %%
import pandas as pd

def get_fields(json_data):
    title = [delete_tag(each["title"]) for each in json_data["items"]]
    link = [each["link"] for each in json_data["items"]]
    lprice = [each["lprice"] for each in json_data["items"]]
    mallName = [each["mallName"] for each in json_data["items"]]
    
    result_pd = pd.DataFrame({
        "title" : title,
        "link" : link,
        "lprice" : lprice,
        "mallName" : mallName        
    }, columns = ["title", "lprice", "link", "mallName"])
    
    return result_pd

# %%
get_fields(one_result)
# Out:
#                                    title lprice  \
# 0              몰스킨 2024 위클리 다이어리 포켓 상품선택  29460
# 1          올젠 남성 가을겨울 몰스킨 자켓 ZOC3KG13122  70390
# 2              로이텀 2024 다이어리 데일리 하드커버 A5  31450
# 3  인디안 INDIAN 오리지널 몰스킨 셋업 자켓 MITFAWF9101  56380
# 4              몰스킨 2024 위클리 다이어리 라지 상품선택  38760
#
#                                                 link mallName
# 0  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...   몰스킨스토어
# 3  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...      네이버

# %%
url = get_search_url("shop", "몰스킨", 1, 5)
json_result = get_result_onpage(url)
pd_result = get_fields(json_result)
pd_result
# Out:
# [2023-10-30 17:58:53.074281] Url Request Success
#                                    title lprice  \
# 0              몰스킨 2024 위클리 다이어리 포켓 상품선택  29460
# 1          올젠 남성 가을겨울 몰스킨 자켓 ZOC3KG13122  70390
# 2              로이텀 2024 다이어리 데일리 하드커버 A5  31450
# 3  인디안 INDIAN 오리지널 몰스킨 셋업 자켓 MITFAWF9101  56380
# 4              몰스킨 2024 위클리 다이어리 라지 상품선택  38760
#
#                                                 link mallName
# 0  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...   몰스킨스토어
# 3  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...      네이버

# %% [markdown]
# ## (4) actMain : 앞서 만든 함수들을 실제로 실행시켜 데이터를 수집해주는 함수

# %%
for n in range(1,1000,100):
    print(n)
# Out:
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901

# %%
result_mol = [] 

for n in range(1, 1000, 100):
    url = get_search_url("shop", "몰스킨", n, 100)
    json_result = get_result_onpage(url)
    pd_result = get_fields(json_result)
    
    result_mol.append(pd_result)
    
result_mol = pd.concat(result_mol)
# Out:
# [2023-10-30 18:57:46.020074] Url Request Success
# [2023-10-30 18:57:46.551649] Url Request Success
# [2023-10-30 18:57:47.064606] Url Request Success
# [2023-10-30 18:57:47.395759] Url Request Success
# [2023-10-30 18:57:47.656616] Url Request Success
# [2023-10-30 18:57:47.971374] Url Request Success
# [2023-10-30 18:57:48.452718] Url Request Success
# [2023-10-30 18:57:48.740861] Url Request Success
# [2023-10-30 18:57:49.003569] Url Request Success
# [2023-10-30 18:57:49.330654] Url Request Success

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     1000 non-null   object
#  1   lprice    1000 non-null   object
#  2   link      1000 non-null   object
#  3   mallName  1000 non-null   object
# dtypes: object(4)
# memory usage: 39.1+ KB

# %%
result_mol.head()
# Out:
#                                    title lprice  \
# 0              몰스킨 2024 위클리 다이어리 포켓 상품선택  29460
# 1          올젠 남성 가을겨울 몰스킨 자켓 ZOC3KG13122  70390
# 2              로이텀 2024 다이어리 데일리 하드커버 A5  31450
# 3  인디안 INDIAN 오리지널 몰스킨 셋업 자켓 MITFAWF9101  56380
# 4              몰스킨 2024 위클리 다이어리 라지 상품선택  38760
#
#                                                 link mallName
# 0  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...   몰스킨스토어
# 3  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...      네이버

# %%
result_mol.tail() # 데이터는 1000개인데 index가 이상하다.
# Out:
#                                                 title  lprice  \
# 95  풀카운트 FULLCOUNT 2022 프렌치 몰스킨 워크 재킷 French Moles...  332370
# 96                         무료각인 몰스킨 플레인 사파이어블루 소프트 포켓   23410
# 97                        몰스킨 무료각인 룰드 노트 하드 라지 -스칼렛레드   33830
# 98                      몰스킨 무료각인 플레인 노트 소프트 라지 -어스브라운   32570
# 99   몰스킨 Moleskine 한정판 노트북 토끼의 해 라지 유선 엔젤 첸 12 7 x 21   36520
#
#                                                  link mallName
# 95  https://search.shopping.naver.com/gate.nhn?id=...     럽인도쿄
# 96  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 97  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 98  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 99  https://search.shopping.naver.com/gate.nhn?id=...      네이버

# %%
result_mol.reset_index(drop = True, inplace = True)
result_mol
# Out:
#                                                  title  lprice  \
# 0                            몰스킨 2024 위클리 다이어리 포켓 상품선택   29460
# 1                        올젠 남성 가을겨울 몰스킨 자켓 ZOC3KG13122   70390
# 2                            로이텀 2024 다이어리 데일리 하드커버 A5   31450
# 3                인디안 INDIAN 오리지널 몰스킨 셋업 자켓 MITFAWF9101   56380
# 4                            몰스킨 2024 위클리 다이어리 라지 상품선택   38760
# ..                                                 ...     ...
# 995  풀카운트 FULLCOUNT 2022 프렌치 몰스킨 워크 재킷 French Moles...  332370
# 996                         무료각인 몰스킨 플레인 사파이어블루 소프트 포켓   23410
# 997                        몰스킨 무료각인 룰드 노트 하드 라지 -스칼렛레드   33830
# 998                      몰스킨 무료각인 플레인 노트 소프트 라지 -어스브라운   32570
# 999   몰스킨 Moleskine 한정판 노트북 토끼의 해 라지 유선 엔젤 첸 12 7 x 21   36520
#
#                                                   link mallName
# 0    https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 1    https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 2    https://search.shopping.naver.com/gate.nhn?id=...   몰스킨스토어
# 3    https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 4    https://search.shopping.naver.com/gate.nhn?id=...      네이버
# ..                                                 ...      ...
# 995  https://search.shopping.naver.com/gate.nhn?id=...     럽인도쿄
# 996  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 997  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 998  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 999  https://search.shopping.naver.com/gate.nhn?id=...      네이버
#
# [1000 rows x 4 columns]

# %%
result_mol["mallName"].unique()
# Out:
# array(['네이버', '몰스킨스토어', '베스트펜', '독집사', '유니스스토어', '스프링스트릿 마켓', '루비샵',
#        'Owl Hunter', '지이크파렌하이트 부산대점', '트러스트앤빌리프', '29CM', 'pink basket',
#        '펜카페스토어', '무신사', '한정판매니아', '올젠 현대시티아울렛대구점', '텐바이텐', 'CHICKPEAS',
#        '클리크', '화요일의집', '안네프랑크', '럽인도쿄'], dtype=object)

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     1000 non-null   object
#  1   lprice    1000 non-null   object
#  2   link      1000 non-null   object
#  3   mallName  1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %%
result_mol["lprice"] = result_mol["lprice"].astype("float")
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     1000 non-null   object
#  1   lprice    1000 non-null   float64
#  2   link      1000 non-null   object
#  3   mallName  1000 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 31.4+ KB

# %% [markdown]
# # (5) toExcel : 최종적으로 엑셀 파일에 저장해주는 함수

# %%
pip install xlsxwriter
# Out:
# Requirement already satisfied: xlsxwriter in /Users/aragbagofideas/anaconda3/lib/python3.9/site-packages (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 엑셀 작업을 파이썬으로 하는 법

writer = pd.ExcelWriter("../data/06_molskin_diary_in_naver_shop.xlsx", engine="xlsxwriter")
result_mol.to_excel(writer, sheet_name="Sheet1")

workbook = writer.book 
worksheet = writer.sheets["Sheet1"]
                    # 행:열 , 간격
worksheet.set_column("A:A", 4) 
worksheet.set_column("B:B", 60)
worksheet.set_column("C:C", 10)
worksheet.set_column("D:D", 10)
worksheet.set_column("E:E", 50)
worksheet.set_column("F:F", 10)

worksheet.conditional_format("C2:C1001", {"type": "3_color_scale"})
writer.save()

# %%
import os.path
from os import path

path.exists("../data/06_molskin_diary_in_naver_shop.xlsx")
# Out:
# True

# %%
df = pd.read_excel("../data/06_molskin_diary_in_naver_shop.xlsx")

del df["Unnamed: 0"]
df.head()
# Out:
#                                    title  lprice  \
# 0              몰스킨 2024 위클리 다이어리 포켓 상품선택   29460
# 1          올젠 남성 가을겨울 몰스킨 자켓 ZOC3KG13122   70390
# 2              로이텀 2024 다이어리 데일리 하드커버 A5   31450
# 3  인디안 INDIAN 오리지널 몰스킨 셋업 자켓 MITFAWF9101   56380
# 4              몰스킨 2024 위클리 다이어리 라지 상품선택   38760
#
#                                                 link mallName
# 0  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...   몰스킨스토어
# 3  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...      네이버

# %% [markdown]
# # (6) 시각화

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import platform
from matplotlib import font_manager, rc

rc('font', family='Arial Unicode MS')

# %matplotlib inline

# %%
plt.figure(figsize = (15,6))
sns.countplot(
    x = "mallName",
    data = result_mol,
    palette = "RdYlGn",
    order = result_mol["mallName"].value_counts().index
)
plt.xticks(rotation = 90) # x축의 각 값들을 90도 눕혀서 보여줌
plt.show()
